# %%
import numpy as np
students = np.array([
    [67, 94, 65],
    [78, 92, 68],
    [59, 92, 87]
    ])
students
# Out:
# array([[67, 94, 65],
#        [78, 92, 68],
#        [59, 92, 87]])

# %%
import pandas as pd

pd.DataFrame(data=students,
            index=['stu1','stu2','stu3'],
            columns=['國文','英文','數學']
            )
# Out:
#       國文  英文  數學
# stu1  67  94  65
# stu2  78  92  68
# stu3  59  92  87

# %%
import random
def get_name(nums:int=10)->list[str]:
    with open('names.txt', encoding='utf-8') as file:
        content = file.read()
        names = content.split("\n")
        randam_names = random.sample(names, nums)
        
    return randam_names
get_name(5)
# Out:
# ['吳麗卿', '金宜芳', '孫火清', '林麗萍', '黃必琪']

# %%
student_nums = 50
data = np.random.randint(50, high=101, size=(student_nums,5))
students = pd.DataFrame(data,
            columns=['國文', '英文', '數學', '地理', '探討'],
            index=get_name(student_nums))
students
# Out:
#       國文   英文   數學  地理  探討
# 崔孝憲   88  100   84  90  52
# 黃靜怡   53   91   90  50  96
# 林康亮   57   54   80  85  81
# 李蓉瑞   73   63   92  90  57
# 林瑞喬   86   50   82  73  55
# 陳逸凡   85   74   78  85  57
# 洪奎夫   78   88   63  93  71
# 陳怡伶  100   69   82  90  91
# 王梅劭   68   53   71  72  87
# 王怡珊   81   93   56  96  89
# 王筱婷   70   58   79  60  65
# 姜琬婷   63   91   58  54  84
# 陳美惠   62   79   57  59  73
# 鄧哲榮   94   80   93  89  62
# 李立偉   51   72   57  90  98
# 王德城   50   70   67  67  81
# 李政白   60   70   79  84  65
# 謝貞妃   98   54   67  91  52
# 劉昀天   95   61   85  52  68
# 吳晴洋   98   51   67  82  55
# 林昱芳   89   89   93  60  67
# 黎惠雯   85   87   72  52  77
# 吳振瑋   80   52   66  52  82
# 林士凱   80   63   97  96  60
# 鄭孟芳   97   96   67  74  50
# 戴萱能   73   77   69  72  91
# 黃詩妃   81   72   93  60  97
# 游一鈺   58   79   66  65  95
# 張俊傑   74   94   60  78  58
# 張凡成  100   71   75  51  79
# 李佳彥   63   57   93  63  54
# 葉軍仰   66   52   76  77  57
# 黃麗美   80   55   53  67  79
# 周怡啟   61   72   65  92  77
# 鄭琇亞   98   58   67  54  57
# 陳志偉   73   70   97  72  70
# 黃健發   62   59   53  65  64
# 鄭奇翰   91   97   68  74  61
# 蔡至剛   61   95   82  66  58
# 黃翔杰   88   81   93  69  73
# 唐翊修   67   64   97  81  61
# 陳信念   84   72   51  56  90
# 彭偉妃   54   74   63  84  93
# 尚偉倫   94   97   99  78  63
# 黃旻林   74   72   84  92  55
# 林建宏   57   95   83  74  67
# 劉旭士   94   64   99  72  85
# 楊建安   50   80   61  57  73
# 劉萬季   73   89   74  64  58
# 馮淑芬   91   78  100  86  75
