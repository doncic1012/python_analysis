# %%
import csv
from pprint import pprint
with open(file='abc.csv', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    homes = list(reader)

pprint(homes)
# Out:
# [{'區域': '宜蘭市',
#   '機構名稱': '國立陽明交通大學附設醫院居家護理所',
#   '機構地址': '宜蘭縣宜蘭市新民路152號',
#   '機構電話': '03-9699410',
#   '編號': '1'},
#  {'區域': '宜蘭市',
#   '機構名稱': '宜蘭仁愛醫療財團法人附設仁愛居家護理所',
#   '機構地址': '宜蘭縣宜蘭市神農里宜興路一段29巷13號',
#   '機構電話': '03-9321888',
#   '編號': '2'},
#  {'區域': '宜蘭市',
#   '機構名稱': '宜蘭縣宜蘭市衛生所附設居家護理所',
#   '機構地址': '宜蘭市健康路二段2-2號2樓',
#   '機構電話': '03-9322362',
#   '編號': '3'},
#  {'區域': '宜蘭市',
#   '機構名稱': '安護居家護理所',
#   '機構地址': '宜蘭縣宜蘭市泰山路503號',
#   '機構電話': '03-9330930',
#   '編號': '4'},
#  {'區域': '宜蘭市',
#   '機構名稱': '迦南居家護理所',
#   '機構地址': '宜蘭縣宜蘭市中山路二段145號9樓之一',
#   '機構電話': '03-9357416',
#   '編號': '5'},
#  {'區域': '宜蘭市',
#   '機構名稱': '家宜居家護理所',
#   '機構地址': '宜蘭縣宜蘭市東津路157號',
#   '機構電話': '0927-077298',
#   '編號': '6'},
#  {'區域': '頭城鎮',
#   '機構名稱': '宜蘭縣頭城鎮衛生所附設居家護理所',
#   '機構地址': '宜蘭縣頭城鎮吉祥路15號',
#   '機構電話': '03-9771034',
#   '編號': '7'},
#  {'區域': '礁溪鄉',
#   '機構名稱': '天主教靈醫會醫療財團法人附設礁溪杏和居家護理所',
#   '機構地址': '宜蘭縣礁溪鄉礁溪路四段129號7樓',
#   '機構電話': '03-9886996',
#   '編號': '8'},
#  {'區域': '礁溪鄉',
# ...
