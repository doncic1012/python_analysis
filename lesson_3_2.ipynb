# %%
p1 = {'name':'陳元浚','age':31,'city':'NewTaiepi'}
p1
# Out:
# {'name': '陳元浚', 'age': 31, 'city': 'NewTaiepi'}

# %%
print(p1['name'])
print(p1.get('age'))
# Out:
# 陳元浚
# 31

# %%
del p1['city']
p1.pop('age')
# Out:
# 31

# %%
del p1

# %%
p1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 p1
#
# NameError: name 'p1' is not defined

# %% [markdown]
# 如何依順序取出串列資料和映射資料的元素值
# for_in迴圈

# %%
fruits = ['蘋果','香蕉','橘子']
for fruit in fruits:
    print(fruit)
# Out:
# 蘋果
# 香蕉
# 橘子

# %%
for index, fruit in enumerate(fruits):
    print(index, fruit,sep='->')
    print('=========')
# Out:
# 0->蘋果
# =========
# 1->香蕉
# =========
# 2->橘子
# =========

# %%
cities = {
    'Taipei': '台北',
    'New Taipei': '新北市',
    'Taoyuan': '桃園',
    'Taichung': '台中',
    'Tainan': '台南',
    'Kaohsiung': '高雄',
    'Keelung': '基隆',
    'Hsinchu': '新竹',
    'Chiayi': '嘉義',
    'Hualien': '花蓮'
}
for key, value in cities.items():
    print(f"{key}: {value}")
# Out:
# Taipei: 台北
# New Taipei: 新北市
# Taoyuan: 桃園
# Taichung: 台中
# Tainan: 台南
# Kaohsiung: 高雄
# Keelung: 基隆
# Hsinchu: 新竹
# Chiayi: 嘉義
# Hualien: 花蓮

# %%
import random

#一個學生(student)的dictionary,格式如下:
#{'name':'value','chinese':78,'english':98,'math':67,'history':87,'health':76}
#請使用list幫我建立50個學生
students = []
students.append({'name': 'Student1', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student2', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student3', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student4', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student5', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student6', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student7', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student8', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student9', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student10', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student11', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student12', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student13', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student14', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student15', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student16', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student17', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student18', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student19', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student20', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student21', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student22', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student23', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student24', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student25', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student26', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student27', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student28', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student29', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student30', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student31', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student32', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student33', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student34', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student35', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student36', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student37', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student38', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student39', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student40', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student41', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student42', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student43', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student44', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student45', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student46', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student47', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student48', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student49', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students.append({'name': 'Student50', 'chinese': random.randint(60, 100), 'english': random.randint(60, 100), 'math': random.randint(60, 100), 'history': random.randint(60, 100), 'health': random.randint(60, 100)})
students
# Out:
# [{'name': 'Student1',
#   'chinese': 70,
#   'english': 81,
#   'math': 75,
#   'history': 62,
#   'health': 95},
#  {'name': 'Student2',
#   'chinese': 82,
#   'english': 63,
#   'math': 72,
#   'history': 100,
#   'health': 75},
#  {'name': 'Student3',
#   'chinese': 63,
#   'english': 72,
#   'math': 88,
#   'history': 84,
#   'health': 96},
#  {'name': 'Student4',
#   'chinese': 87,
#   'english': 91,
#   'math': 91,
#   'history': 79,
#   'health': 73},
#  {'name': 'Student5',
#   'chinese': 65,
#   'english': 90,
#   'math': 98,
#   'history': 95,
#   'health': 96},
#  {'name': 'Student6',
#   'chinese': 90,
#   'english': 88,
#   'math': 77,
#   'history': 88,
#   'health': 77},
#  {'name': 'Student7',
#   'chinese': 76,
#   'english': 64,
#   'math': 97,
#   'history': 65,
#   'health': 85},
#  {'name': 'Student8',
#   'chinese': 60,
#   'english': 76,
#   'math': 83,
#   'history': 75,
#   'health': 84},
#  {'name': 'Student9',
#   'chinese': 60,
#   'english': 87,
#   'math': 76,
#   'history': 76,
#   'health': 74},
#  {'name': 'Student10',
#   'chinese': 98,
#   'english': 64,
#   'math': 99,
#   'history': 88,
#   'health': 72},
#  {'name': 'Student11',
#   'chinese': 92,
#   'english': 70,
#   'math': 62,
#   'history': 72,
#   'health': 64},
#  {'name': 'Student12',
#   'chinese': 89,
#   'english': 68,
#   'math': 98,
#   'history': 83,
#   'health': 81},
#  {'name': 'Student13',
#   'chinese': 81,
#   'english': 90,
#   'math': 84,
#   'history': 92,
#   'health': 100},
#  {'name': 'Student14',
#   'chinese': 90,
#   'english': 100,
#   'math': 100,
#   'history': 87,
#   'health': 84},
#  {'name': 'Student15',
#   'chinese': 89,
#   'english': 65,
#   'math': 62,
#   'history': 95,
#   'health': 94},
#  {'name': 'Student16',
#   'chinese': 88,
#   'english': 70,
#   'math': 71,
#   'history': 60,
#   'health': 83},
#  {'name': 'Student17',
#   'chinese': 90,
#   'english': 90,
#   'math': 80,
#   'history': 77,
#   'health': 80},
#  {'name': 'Student18',
#   'chinese': 62,
#   'english': 76,
#   'math': 66,
#   'history': 65,
#   'health': 82},
#  {'name': 'Student19',
#   'chinese': 98,
#   'english': 87,
#   'math': 96,
#   'history': 73,
#   'health': 77},
#  {'name': 'Student20',
#   'chinese': 90,
#   'english': 87,
#   'math': 66,
#   'history': 95,
#   'health': 62},
#  {'name': 'Student21',
#   'chinese': 92,
#   'english': 94,
#   'math': 89,
#   'history': 87,
#   'health': 92},
#  {'name': 'Student22',
#   'chinese': 91,
#   'english': 86,
#   'math': 68,
#   'history': 80,
#   'health': 89},
#  {'name': 'Student23',
#   'chinese': 81,
#   'english': 60,
#   'math': 90,
#   'history': 63,
#   'health': 62},
#  {'name': 'Student24',
#   'chinese': 78,
#   'english': 78,
#   'math': 78,
#   'history': 98,
#   'health': 100},
#  {'name': 'Student25',
#   'chinese': 76,
#   'english': 71,
#   'math': 93,
#   'history': 86,
#   'health': 67},
#  {'name': 'Student26',
#   'chinese': 80,
#   'english': 62,
#   'math': 71,
#   'history': 84,
#   'health': 79},
#  {'name': 'Student27',
#   'chinese': 87,
#   'english': 99,
#   'math': 88,
#   'history': 94,
#   'health': 64},
#  {'name': 'Student28',
#   'chinese': 79,
#   'english': 65,
#   'math': 79,
#   'history': 79,
#   'health': 63},
#  {'name': 'Student29',
#   'chinese': 72,
#   'english': 66,
#   'math': 82,
#   'history': 87,
#   'health': 88},
#  {'name': 'Student30',
#   'chinese': 99,
#   'english': 71,
#   'math': 85,
#   'history': 83,
#   'health': 72},
#  {'name': 'Student31',
#   'chinese': 66,
#   'english': 100,
#   'math': 61,
#   'history': 94,
#   'health': 74},
#  {'name': 'Student32',
#   'chinese': 74,
#   'english': 97,
#   'math': 78,
#   'history': 68,
#   'health': 81},
#  {'name': 'Student33',
#   'chinese': 94,
#   'english': 78,
#   'math': 94,
#   'history': 90,
#   'health': 87},
#  {'name': 'Student34',
#   'chinese': 75,
#   'english': 81,
#   'math': 67,
#   'history': 68,
#   'health': 73},
#  {'name': 'Student35',
#   'chinese': 69,
#   'english': 84,
#   'math': 81,
#   'history': 67,
#   'health': 72},
#  {'name': 'Student36',
#   'chinese': 75,
#   'english': 62,
#   'math': 100,
#   'history': 73,
#   'health': 87},
#  {'name': 'Student37',
#   'chinese': 87,
#   'english': 88,
#   'math': 80,
#   'history': 65,
#   'health': 63},
#  {'name': 'Student38',
#   'chinese': 80,
#   'english': 79,
#   'math': 84,
#   'history': 91,
#   'health': 95},
#  {'name': 'Student39',
#   'chinese': 70,
#   'english': 81,
#   'math': 67,
#   'history': 94,
#   'health': 82},
#  {'name': 'Student40',
#   'chinese': 94,
#   'english': 93,
#   'math': 94,
#   'history': 70,
#   'health': 71},
#  {'name': 'Student41',
#   'chinese': 86,
#   'english': 74,
#   'math': 71,
#   'history': 79,
#   'health': 98},
#  {'name': 'Student42',
#   'chinese': 63,
#   'english': 82,
#   'math': 64,
#   'history': 79,
#   'health': 64},
#  {'name': 'Student43',
#   'chinese': 93,
#   'english': 81,
#   'math': 78,
#   'history': 67,
#   'health': 61},
#  {'name': 'Student44',
#   'chinese': 86,
#   'english': 82,
#   'math': 82,
#   'history': 60,
#   'health': 81},
#  {'name': 'Student45',
#   'chinese': 74,
#   'english': 97,
#   'math': 93,
#   'history': 62,
#   'health': 87},
#  {'name': 'Student46',
#   'chinese': 94,
#   'english': 97,
#   'math': 79,
#   'history': 97,
#   'health': 71},
#  {'name': 'Student47',
#   'chinese': 93,
#   'english': 76,
#   'math': 79,
#   'history': 93,
#   'health': 100},
#  {'name': 'Student48',
#   'chinese': 72,
#   'english': 65,
#   'math': 87,
#   'history': 84,
#   'health': 96},
#  {'name': 'Student49',
#   'chinese': 72,
#   'english': 66,
#   'math': 75,
#   'history': 73,
#   'health': 93},
#  {'name': 'Student50',
#   'chinese': 65,
#   'english': 85,
#   'math': 60,
#   'history': 84,
#   'health': 78}]

# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'student{i}',
            'chinese':random.randint(50,100),
            'english':random.randint(50,100),
            'math':random.randint(50,100),
            'history':random.randint(50,100),
            'health':random.randint(50,100)
        }
    )

students_str = str(students)
students_str
# Out:
# "[{'name': 'student1', 'chinese': 99, 'english': 51, 'math': 92, 'history': 78, 'health': 62}, {'name': 'student2', 'chinese': 99, 'english': 96, 'math': 56, 'history': 94, 'health': 81}, {'name': 'student3', 'chinese': 99, 'english': 69, 'math': 63, 'history': 86, 'health': 77}, {'name': 'student4', 'chinese': 56, 'english': 53, 'math': 67, 'history': 85, 'health': 85}, {'name': 'student5', 'chinese': 70, 'english': 52, 'math': 89, 'history': 78, 'health': 63}, {'name': 'student6', 'chinese': 52, 'english': 56, 'math': 87, 'history': 83, 'health': 55}, {'name': 'student7', 'chinese': 85, 'english': 55, 'math': 72, 'history': 62, 'health': 90}, {'name': 'student8', 'chinese': 78, 'english': 95, 'math': 79, 'history': 91, 'health': 59}, {'name': 'student9', 'chinese': 88, 'english': 75, 'math': 61, 'history': 91, 'health': 75}, {'name': 'student10', 'chinese': 64, 'english': 99, 'math': 85, 'history': 87, 'health': 99}, {'name': 'student11', 'chinese': 87, 'english': 75, 'math': 80, 'history': 62, 'health': 99}, {'name': 'student12', 'chinese': 78, 'english': 93, 'math': 85, 'history': 61, 'health': 67}, {'name': 'student13', 'chinese': 65, 'english': 69, 'math': 53, 'history': 93, 'health': 91}, {'name': 'student14', 'chinese': 76, 'english': 97, 'math': 61, 'history': 63, 'health': 100}, {'name': 'student15', 'chinese': 59, 'english': 89, 'math': 52, 'history': 83, 'health': 59}, {'name': 'student16', 'chinese': 82, 'english': 51, 'math': 52, 'history': 76, 'health': 62}, {'name': 'student17', 'chinese': 88, 'english': 92, 'math': 68, 'history': 88, 'health': 63}, {'name': 'student18', 'chinese': 87, 'english': 99, 'math': 81, 'history': 86, 'health': 100}, {'name': 'student19', 'chinese': 73, 'english': 71, 'math': 63, 'history': 60, 'health': 72}, {'name': 'student20', 'chinese': 61, 'english': 64, 'math': 83, 'history': 60, 'health': 55}, {'name': 'student21', 'chinese': 78, 'english': 64, 'math': 75, 'history': 50, 'health': 83}, {'name': 'student22', 'chinese': 74, 'english': 52, 'math': 77, 'history': 65, 'health': 63}, {'name': 'student23', 'chinese': 98, 'english': 84, 'math': 89, 'history': 83, 'health': 85}, {'name': 'student24', 'chinese': 68, 'english': 65, 'math': 57, 'history': 58, 'health': 78}, {'name': 'student25', 'chinese': 82, 'english': 74, 'math': 64, 'history': 54, 'health': 80}, {'name': 'student26', 'chinese': 79, 'english': 71, 'math': 90, 'history': 94, 'health': 87}, {'name': 'student27', 'chinese': 55, 'english': 76, 'math': 81, 'history': 69, 'health': 62}, {'name': 'student28', 'chinese': 92, 'english': 75, 'math': 92, 'history': 79, 'health': 79}, {'name': 'student29', 'chinese': 70, 'english': 90, 'math': 86, 'history': 65, 'health': 93}, {'name': 'student30', 'chinese': 68, 'english': 93, 'math': 68, 'history': 80, 'health': 56}, {'name': 'student31', 'chinese': 74, 'english': 71, 'math': 66, 'history': 53, 'health': 51}, {'name': 'student32', 'chinese': 89, 'english': 75, 'math': 92, 'history': 79, 'health': 95}, {'name': 'student33', 'chinese': 70, 'english': 88, 'math': 74, 'history': 57, 'health': 99}, {'name': 'student34', 'chinese': 58, 'english': 96, 'math': 100, 'history': 56, 'health': 52}, {'name': 'student35', 'chinese': 99, 'english': 74, 'math': 52, 'history': 57, 'health': 54}, {'name': 'student36', 'chinese': 65, 'english': 56, 'math': 59, 'history': 84, 'health': 55}, {'name': 'student37', 'chinese': 98, 'english': 76, 'math': 85, 'history': 57, 'health': 86}, {'name': 'student38', 'chinese': 64, 'english': 64, 'math': 50, 'history': 76, 'health': 68}, {'name': 'student39', 'chinese': 50, 'english': 67, 'math': 51, 'history': 81, 'health': 100}, {'name': 'student40', 'chinese': 93, 'english': 54, 'math': 98, 'history': 69, 'health': 91}, {'name': 'student41', 'chinese': 68, 'english': 51, 'math': 52, 'history': 56, 'health': 79}, {'name': 'student42', 'chinese': 84, 'english': 66, 'math': 55, 'history': 56, 'health': 71}, {'name': 'student43', 'chinese': 84, 'english': 63, 'ma ...

# %%
for scores in students:
    print(scores)
# Out:
# {'name': 'student1', 'chinese': 53, 'english': 82, 'math': 96, 'history': 89, 'health': 68}
# {'name': 'student2', 'chinese': 58, 'english': 90, 'math': 65, 'history': 72, 'health': 62}
# {'name': 'student3', 'chinese': 99, 'english': 96, 'math': 83, 'history': 76, 'health': 54}
# {'name': 'student4', 'chinese': 57, 'english': 88, 'math': 70, 'history': 82, 'health': 52}
# {'name': 'student5', 'chinese': 64, 'english': 70, 'math': 80, 'history': 81, 'health': 59}
# {'name': 'student6', 'chinese': 86, 'english': 59, 'math': 57, 'history': 68, 'health': 100}
# {'name': 'student7', 'chinese': 81, 'english': 89, 'math': 80, 'history': 54, 'health': 99}
# {'name': 'student8', 'chinese': 55, 'english': 64, 'math': 80, 'history': 74, 'health': 100}
# {'name': 'student9', 'chinese': 54, 'english': 75, 'math': 96, 'history': 94, 'health': 90}
# {'name': 'student10', 'chinese': 58, 'english': 63, 'math': 89, 'history': 70, 'health': 78}
# {'name': 'student11', 'chinese': 96, 'english': 98, 'math': 71, 'history': 100, 'health': 93}
# {'name': 'student12', 'chinese': 93, 'english': 90, 'math': 99, 'history': 65, 'health': 82}
# {'name': 'student13', 'chinese': 54, 'english': 53, 'math': 73, 'history': 74, 'health': 79}
# {'name': 'student14', 'chinese': 86, 'english': 52, 'math': 64, 'history': 78, 'health': 79}
# {'name': 'student15', 'chinese': 73, 'english': 55, 'math': 54, 'history': 81, 'health': 85}
# {'name': 'student16', 'chinese': 95, 'english': 75, 'math': 76, 'history': 88, 'health': 57}
# {'name': 'student17', 'chinese': 83, 'english': 98, 'math': 91, 'history': 81, 'health': 54}
# {'name': 'student18', 'chinese': 78, 'english': 82, 'math': 58, 'history': 76, 'health': 62}
# {'name': 'student19', 'chinese': 83, 'english': 74, 'math': 56, 'history': 51, 'health': 84}
# {'name': 'student20', 'chinese': 75, 'english': 97, 'math': 94, 'history': 51, 'health': 62}
# {'name': 'student21', 'chinese': 73, 'english': 59, 'math': 77, 'history': 75, 'health': 66}
# {'name': 'student22', 'chinese': 70, 'english': 59, 'math': 71, 'history': 57, 'health': 56}
# {'name': 'student23', 'chinese': 80, 'english': 96, 'math': 87, 'history': 76, 'health': 76}
# {'name': 'student24', 'chinese': 73, 'english': 60, 'math': 61, 'history': 64, 'health': 75}
# {'name': 'student25', 'chinese': 95, 'english': 56, 'math': 68, 'history': 73, 'health': 84}
# {'name': 'student26', 'chinese': 72, 'english': 79, 'math': 95, 'history': 91, 'health': 58}
# {'name': 'student27', 'chinese': 66, 'english': 53, 'math': 89, 'history': 56, 'health': 56}
# {'name': 'student28', 'chinese': 78, 'english': 57, 'math': 69, 'history': 95, 'health': 70}
# {'name': 'student29', 'chinese': 54, 'english': 50, 'math': 78, 'history': 72, 'health': 59}
# {'name': 'student30', 'chinese': 63, 'english': 74, 'math': 82, 'history': 58, 'health': 58}
# {'name': 'student31', 'chinese': 80, 'english': 56, 'math': 68, 'history': 70, 'health': 66}
# {'name': 'student32', 'chinese': 59, 'english': 66, 'math': 73, 'history': 67, 'health': 71}
# {'name': 'student33', 'chinese': 79, 'english': 91, 'math': 98, 'history': 83, 'health': 70}
# {'name': 'student34', 'chinese': 86, 'english': 64, 'math': 92, 'history': 59, 'health': 70}
# {'name': 'student35', 'chinese': 84, 'english': 71, 'math': 82, 'history': 50, 'health': 96}
# {'name': 'student36', 'chinese': 53, 'english': 82, 'math': 83, 'history': 69, 'health': 70}
# {'name': 'student37', 'chinese': 62, 'english': 64, 'math': 84, 'history': 53, 'health': 87}
# {'name': 'student38', 'chinese': 83, 'english': 79, 'math': 97, 'history': 55, 'health': 80}
# {'name': 'student39', 'chinese': 76, 'english': 63, 'math': 60, 'history': 60, 'health': 85}
# {'name': 'student40', 'chinese': 90, 'english': 73, 'math': 75, 'history': 84, 'health': 83}
# {'name': 'student41', 'chinese': 51, 'english': 84, 'math': 62, 'history': 76, 'health': 63}
# {'name': 'student42', 'chinese': 57, 'english': 86, 'math': 78, 'history': 58, 'health': 60}
# {'name': 'student43', 'chinese': 69, 'english': 54, 'math': 70, 'history': 97, 'health': 83}
# {'name': 'student44', 'chinese': 100, 'english': 55, 'math': 68, 'history': 86, 'health': 65}
# {'name': 'student45', 'chinese': 92, 'english': 93, 'math': 73, 'history': 88, 'health': 93}
# {'name': 'student46', 'chinese': 57, 'english': 93, 'math': 56, 'history': 86, 'health': 71}
# {'name': 'student47', 'chinese': 64, 'english': 98, 'math': 91, 'history': 63, 'health': 52}
# {'name': 'student48', 'chinese': 58, 'english': 59, 'math': 64, 'history': 60, 'health': 53}
# {'name': 'student49', 'chinese': 87, 'english': 87, 'math': 89, 'history': 52, 'health': 85}
# {'name': 'student50', 'chinese': 60, 'english': 67, 'math': 93, 'history': 94, 'health': 51}

# %%
# 將 students 列表轉換為字串
students_str = '\n'.join([
    f"姓名:{student['name']}, "
    f"國文:{student['chinese']}, "
    f"英文:{student['english']}, "
    f"數學:{student['math']}, "
    f"歷史:{student['history']}, "
    f"健康:{student['health']}"
    for student in students
])

print(students_str)
# Out:
# 姓名:student1, 國文:99, 英文:51, 數學:92, 歷史:78, 健康:62
# 姓名:student2, 國文:99, 英文:96, 數學:56, 歷史:94, 健康:81
# 姓名:student3, 國文:99, 英文:69, 數學:63, 歷史:86, 健康:77
# 姓名:student4, 國文:56, 英文:53, 數學:67, 歷史:85, 健康:85
# 姓名:student5, 國文:70, 英文:52, 數學:89, 歷史:78, 健康:63
# 姓名:student6, 國文:52, 英文:56, 數學:87, 歷史:83, 健康:55
# 姓名:student7, 國文:85, 英文:55, 數學:72, 歷史:62, 健康:90
# 姓名:student8, 國文:78, 英文:95, 數學:79, 歷史:91, 健康:59
# 姓名:student9, 國文:88, 英文:75, 數學:61, 歷史:91, 健康:75
# 姓名:student10, 國文:64, 英文:99, 數學:85, 歷史:87, 健康:99
# 姓名:student11, 國文:87, 英文:75, 數學:80, 歷史:62, 健康:99
# 姓名:student12, 國文:78, 英文:93, 數學:85, 歷史:61, 健康:67
# 姓名:student13, 國文:65, 英文:69, 數學:53, 歷史:93, 健康:91
# 姓名:student14, 國文:76, 英文:97, 數學:61, 歷史:63, 健康:100
# 姓名:student15, 國文:59, 英文:89, 數學:52, 歷史:83, 健康:59
# 姓名:student16, 國文:82, 英文:51, 數學:52, 歷史:76, 健康:62
# 姓名:student17, 國文:88, 英文:92, 數學:68, 歷史:88, 健康:63
# 姓名:student18, 國文:87, 英文:99, 數學:81, 歷史:86, 健康:100
# 姓名:student19, 國文:73, 英文:71, 數學:63, 歷史:60, 健康:72
# 姓名:student20, 國文:61, 英文:64, 數學:83, 歷史:60, 健康:55
# 姓名:student21, 國文:78, 英文:64, 數學:75, 歷史:50, 健康:83
# 姓名:student22, 國文:74, 英文:52, 數學:77, 歷史:65, 健康:63
# 姓名:student23, 國文:98, 英文:84, 數學:89, 歷史:83, 健康:85
# 姓名:student24, 國文:68, 英文:65, 數學:57, 歷史:58, 健康:78
# 姓名:student25, 國文:82, 英文:74, 數學:64, 歷史:54, 健康:80
# 姓名:student26, 國文:79, 英文:71, 數學:90, 歷史:94, 健康:87
# 姓名:student27, 國文:55, 英文:76, 數學:81, 歷史:69, 健康:62
# 姓名:student28, 國文:92, 英文:75, 數學:92, 歷史:79, 健康:79
# 姓名:student29, 國文:70, 英文:90, 數學:86, 歷史:65, 健康:93
# 姓名:student30, 國文:68, 英文:93, 數學:68, 歷史:80, 健康:56
# 姓名:student31, 國文:74, 英文:71, 數學:66, 歷史:53, 健康:51
# 姓名:student32, 國文:89, 英文:75, 數學:92, 歷史:79, 健康:95
# 姓名:student33, 國文:70, 英文:88, 數學:74, 歷史:57, 健康:99
# 姓名:student34, 國文:58, 英文:96, 數學:100, 歷史:56, 健康:52
# 姓名:student35, 國文:99, 英文:74, 數學:52, 歷史:57, 健康:54
# 姓名:student36, 國文:65, 英文:56, 數學:59, 歷史:84, 健康:55
# 姓名:student37, 國文:98, 英文:76, 數學:85, 歷史:57, 健康:86
# 姓名:student38, 國文:64, 英文:64, 數學:50, 歷史:76, 健康:68
# 姓名:student39, 國文:50, 英文:67, 數學:51, 歷史:81, 健康:100
# 姓名:student40, 國文:93, 英文:54, 數學:98, 歷史:69, 健康:91
# 姓名:student41, 國文:68, 英文:51, 數學:52, 歷史:56, 健康:79
# 姓名:student42, 國文:84, 英文:66, 數學:55, 歷史:56, 健康:71
# 姓名:student43, 國文:84, 英文:63, 數學:65, 歷史:60, 健康:68
# 姓名:student44, 國文:86, 英文:78, 數學:58, 歷史:93, 健康:58
# 姓名:student45, 國文:78, 英文:62, 數學:91, 歷史:96, 健康:93
# 姓名:student46, 國文:98, 英文:63, 數學:54, 歷史:53, 健康:55
# 姓名:student47, 國文:73, 英文:50, 數學:77, 歷史:51, 健康:85
# 姓名:student48, 國文:98, 英文:73, 數學:83, 歷史:100, 健康:60
# 姓名:student49, 國文:98, 英文:52, 數學:83, 歷史:77, 健康:67
# 姓名:student50, 國文:59, 英文:95, 數學:78, 歷史:70, 健康:68

# %%
print(students_str,file=open('students.txt',mode='w',encoding='utf-8',))
